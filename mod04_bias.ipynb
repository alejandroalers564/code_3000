# %%
# import packages
# %pip install matplotlib shap
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import shap
import matplotlib.pyplot as plt
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      ---------------------- --------------- 30.7/52.8 kB 259.2 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 387.2 kB/s eta 0:00:00
# Requirement already satisfied: shap in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.50.0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl.metadata (116 kB)
#      ---------------------------------------- 0.0/116.4 kB ? eta -:--:--
#      ------------------------------------ - 112.6/116.4 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 116.4/116.4 kB 3.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from shap) (1.17.0)
# Requirement already satisfied: scikit-learn in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from shap) (1.8.0)
# Requirement already satisfied: pandas in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from shap) (3.0.0)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from shap) (4.67.3)
# Requirement already satisfied: slicer==0.0.8 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from shap) (0.64.0)
# Requirement already satisfied: cloudpickle in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from numba>=0.54->shap) (0.46.0)
# Requirement already satisfied: six>=1.5 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: colorama in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: tzdata in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->shap) (3.6.0)
# Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 15.2 MB/s eta 0:00:01
#    --------- ------------------------------ 1.9/8.1 MB 24.8 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 44.2 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 52.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 37.1 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    ---------------------------------------- 225.2/225.2 kB ? eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 72.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.8 kB ? eta -:--:--
#    ---------------------------------------- 73.8/73.8 kB ? eta 0:00:00
# Downloading pillow-12.1.1-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    --------------------- ------------------ 3.8/7.0 MB 120.9 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 89.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 56.2 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.8 kB ? eta -:--:--
#    ---------------------------------------- 122.8/122.8 kB ? eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Aleja\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
seed = 2724

# %% [markdown]
# ### Import data

# %%
DF_PATH = "mod04_data/sample.csv"
df = pd.read_csv(DF_PATH)

# %% [markdown]
# ### Separate data by independent (X) and dependent (y) variables

# %%
X = df[["income", "education_years", "zipcode_score"]]
y = df["target"]

# %% [markdown]
# ### Split the data into a _training_ set (to build a model) and _test_ set (to validate a model)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=seed
)

# %% [markdown]
# ### Build a model on the training set

# %%
model = RandomForestRegressor(
    n_estimators=200,
    random_state=seed
)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=2724)

# %% [markdown]
# ### Use SHAP to explain the model on test data

# %%
explainer = shap.Explainer(model, X_train)
shap_values = explainer(X_test)
# Out:
#  99%|===================| 1487/1500 [01:12<00:00]

# %% [markdown]
# This will allow us to see which variables are most important to predicting the outcome.

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt

shap.plots.bar(shap_values)
# Out:
# Requirement already satisfied: matplotlib in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\aleja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Aleja\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 4
#       1 get_ipython().run_line_magic('pip', 'install matplotlib')
#       2 import matplotlib.pyplot as plt
# ----> 4 shap.plots.bar(shap_values)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\__init__.py:38, in UnsupportedModule.__getattribute__(self, item)
#      37 def __getattribute__(self, item):
# ---> 38     raise ImportError(_no_matplotlib_warning)
#
# ImportError: matplotlib is not installed so plotting is not available! Run `pip install matplotlib` to fix this.

# %% [markdown]
# ### Import the `group` variable, which was **not** used in training this model.

# %%
X_test_with_group = X_test.copy()
X_test_with_group["group"] = df.loc[X_test.index, "group"]

# %% [markdown]
# ### Look at the difference in SHAP values between the two groups across the variables used in the model.

# %%
shap_df = pd.DataFrame(shap_values.values, columns=X_test.columns)
shap_df["group"] = X_test_with_group["group"].values

shap_df.groupby("group").mean()

# %% [markdown]
# ### Let's put `group` and `zipcode_score` in the same plot

# %%
def plot_shap(var):
    # Extract SHAP values for the feature
    shap_var = shap_values[:, var].values

    # Plot the values of each group using different colors
    plt.figure()
    plt.scatter(
        X_test[var],
        shap_var,
        c=X_test_with_group["group"]
    )
    plt.xlabel(var)
    plt.ylabel(f"SHAP value for var")
    plt.title("Proxy feature impact by group")
    plt.show()

plot_shap("zipcode_score")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 17
#      14     plt.title("Proxy feature impact by group")
#      15     plt.show()
# ---> 17 plot_shap("zipcode_score")
#
# Cell In[5], line 3, in plot_shap(var)
#       1 def plot_shap(var):
#       2     # Extract SHAP values for the feature
# ----> 3     shap_var = shap_values[:, var].values
#       5     # Plot the values of each group using different colors
#       6     plt.figure()
#
# NameError: name 'shap_values' is not defined

# %% [markdown]
# # Discussion Questions

# %% [markdown]
# ### What is a _SHAP_ (or Shapley) value?

# %% [markdown]
# Type your answer here

# %% [markdown]
# ### Suppose you built this model and then it is peer reviewed by another entity. If the reviewer asks whether you used the variable `group` in your model, what would your answer be?

# %% [markdown]
# Type your answer here

# %% [markdown]
# ### If the reviewer asks whether the outcome of your model is correlated with `group`, what would your answer be?

# %% [markdown]
# Type your answer here

# %% [markdown]
# ### Construct a "proxy feature impact by group" plot for `income`. How is this plot different from the one for `zipcode_score`?

# %% [markdown]
# Type your answer here.

# %% [markdown]
# ### If, instead, you were the **reviewer**, what other questions might you ask the person who built this model? Give at least two.

# %% [markdown]
# Type your answer here.
